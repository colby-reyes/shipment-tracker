# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting great_expectations
#   Downloading great_expectations-0.15.17-py3-none-any.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 80.6 MB/s eta 0:00:00
# Requirement already satisfied: pydantic in /shared-libs/python3.10/py/lib/python3.10/site-packages (from -r ./requirements.txt (line 2)) (1.9.1)
# Requirement already satisfied: scipy>=0.19.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: cryptography>=3.2 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (36.0.2)
# Requirement already satisfied: mistune>=0.8.4 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: Click>=7.1.2 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (8.1.3)
# Collecting pyparsing<3,>=2.4
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: tzlocal>=1.2 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (4.2)
# Requirement already satisfied: Ipython>=7.16.3 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (8.4.0)
# Requirement already satisfied: altair<5,>=4.0.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: pytz>=2021.3 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: notebook>=6.4.10 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (6.4.12)
# Collecting ruamel.yaml<0.17.18,>=0.16
#   Downloading ruamel.yaml-0.17.17-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 KB 21.9 MB/s eta 0:00:00
# Requirement already satisfied: nbformat>=5.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (5.4.0)
# Requirement already satisfied: tqdm>=4.59.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (4.3.0)
# Requirement already satisfied: pandas>=0.23.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (1.2.5)
# Requirement already satisfied: packaging in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (1.26.11)
# Requirement already satisfied: jsonschema>=2.5.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: jinja2>=2.10 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (2.11.3)
# Requirement already satisfied: termcolor>=1.1.0 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: requests>=2.20 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: numpy>=1.14.1 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (1.23.1)
# Collecting ipywidgets>=7.5.1
#   Downloading ipywidgets-7.7.1-py2.py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 KB 31.2 MB/s eta 0:00:00
# Collecting colorama>=0.4.3
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from great_expectations->-r ./requirements.txt (line 1)) (2.8.2)
# Collecting importlib-metadata>=1.7.0
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Collecting jsonpatch>=1.22
#   Downloading jsonpatch-1.32-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: entrypoints in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from altair<5,>=4.0.0->great_expectations->-r ./requirements.txt (line 1)) (0.4)
# Requirement already satisfied: toolz in /shared-libs/python3.10/py/lib/python3.10/site-packages (from altair<5,>=4.0.0->great_expectations->-r ./requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: cffi>=1.12 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from cryptography>=3.2->great_expectations->-r ./requirements.txt (line 1)) (1.15.1)
# Collecting zipp>=0.5
#   Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: setuptools>=18.5 in /root/venv/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (58.1.0)
# Requirement already satisfied: backcall in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: stack-data in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (0.1.3)
# Requirement already satisfied: decorator in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (3.0.30)
# Requirement already satisfied: pygments>=2.4.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (2.12.0)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: pickleshare in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (0.17.2)
# Requirement already satisfied: traitlets>=5 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (5.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations->-r ./requirements.txt (line 1)) (0.2.0)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 KB 45.3 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations->-r ./requirements.txt (line 1)) (6.15.1)
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 92.5 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jinja2>=2.10->great_expectations->-r ./requirements.txt (line 1)) (2.0.1)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: six>=1.11.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations->-r ./requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations->-r ./requirements.txt (line 1)) (22.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations->-r ./requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from nbformat>=5.0->great_expectations->-r ./requirements.txt (line 1)) (4.11.1)
# Requirement already satisfied: fastjsonschema in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from nbformat>=5.0->great_expectations->-r ./requirements.txt (line 1)) (2.16.1)
# Requirement already satisfied: nbconvert>=5 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (6.4.5)
# Requirement already satisfied: tornado>=6.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (6.2)
# Requirement already satisfied: pyzmq>=17 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (0.14.1)
# Requirement already satisfied: nest-asyncio>=1.5 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (1.5.5)
# Requirement already satisfied: jupyter-client>=5.3.4 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (7.3.4)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (0.15.0)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (21.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from requests>=2.20->great_expectations->-r ./requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.10/py/lib/python3.10/site-packages (from requests>=2.20->great_expectations->-r ./requirements.txt (line 1)) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from requests>=2.20->great_expectations->-r ./requirements.txt (line 1)) (3.3)
# Requirement already satisfied: pytz-deprecation-shim in /shared-libs/python3.10/py/lib/python3.10/site-packages (from tzlocal>=1.2->great_expectations->-r ./requirements.txt (line 1)) (0.1.0.post0)
# Requirement already satisfied: pycparser in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.2->great_expectations->-r ./requirements.txt (line 1)) (2.21)
# Requirement already satisfied: psutil in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations->-r ./requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: debugpy>=1.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations->-r ./requirements.txt (line 1)) (1.6.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from jedi>=0.16->Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: bleach in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: testpath in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: defusedxml in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from pexpect>4.3->Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from argon2-cffi->notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: tzdata in /shared-libs/python3.10/py/lib/python3.10/site-packages (from pytz-deprecation-shim->tzlocal>=1.2->great_expectations->-r ./requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: pure-eval in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: executing in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (0.9.1)
# Requirement already satisfied: asttokens in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great_expectations->-r ./requirements.txt (line 1)) (2.0.5)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (2.3.2.post1)
# Requirement already satisfied: webencodings in /shared-libs/python3.10/py-core/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=6.4.10->great_expectations->-r ./requirements.txt (line 1)) (0.5.1)
# Installing collected packages: zipp, ruamel.yaml, pyparsing, jupyterlab-widgets, jsonpointer, colorama, jsonpatch, importlib-metadata, widgetsnbextension, ipywidgets, great_expectations
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Not uninstalling pyparsing at /shared-libs/python3.10/py-core/lib/python3.10/site-packages, outside environment /root/venv
#     Can't uninstall 'pyparsing'. No files were found to uninstall.
# Successfully installed colorama-0.4.5 great_expectations-0.15.17 importlib-metadata-4.12.0 ipywidgets-7.7.1 jsonpatch-1.32 jsonpointer-2.3 jupyterlab-widgets-1.1.1 pyparsing-2.4.7 ruamel.yaml-0.17.17 widgetsnbextension-3.6.1 zipp-3.8.1
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=23421d57-1fd0-41ae-ba7e-62fc693f5e69' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
